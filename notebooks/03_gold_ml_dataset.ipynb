# %%
# 03_gold_ml_dataset

**Purpose:**  
Prepare a clean, machine-learning-ready Gold dataset by handling nulls,  
casting labels, and selecting final feature columns.

**Layer:** Gold  
**Input Table:** logistics_silver.shipment_features  
**Output Table:** logistics_gold.ml_delay_dataset

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS logistics_gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %python
from pyspark.sql.functions import col

# %%
silver_df = spark.table("logistics_silver.shipment_features")

# %%
ml_df = silver_df.select(
    "shipment_id",
    "distance_km",
    "shipment_weight_kg",
    "avg_traffic_index",
    "weather_severity_score",
    "historical_delay_rate",
    "avg_delay_days",
    "is_weekend",
    "is_peak_season",
    "is_late"
)

# %%
ml_df_clean = ml_df.fillna({
    "avg_traffic_index": 0.5,
    "weather_severity_score": 0.3,
    "historical_delay_rate": 0.2,
    "avg_delay_days": 1.0
})

# %%
ml_df_clean = ml_df_clean.withColumn(
    "is_late",
    col("is_late").cast("int")
)

# %%
ml_df_clean.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("logistics_gold.ml_delay_dataset")

# %%
# %sql
SELECT COUNT(*) FROM logistics_gold.ml_delay_dataset;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>10000</td></tr></tbody></table></div>

# %%
# %sql
SELECT is_late, COUNT(*) 
FROM logistics_gold.ml_delay_dataset
GROUP BY is_late;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>is_late</th><th>COUNT(*)</th></tr></thead><tbody><tr><td>1</td><td>3543</td></tr><tr><td>0</td><td>6457</td></tr></tbody></table></div>

# %%
# %sql
SELECT
  SUM(CASE WHEN avg_traffic_index IS NULL THEN 1 ELSE 0 END) AS traffic_nulls,
  SUM(CASE WHEN weather_severity_score IS NULL THEN 1 ELSE 0 END) AS weather_nulls
FROM logistics_gold.ml_delay_dataset;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>traffic_nulls</th><th>weather_nulls</th></tr></thead><tbody><tr><td>0</td><td>0</td></tr></tbody></table></div>
